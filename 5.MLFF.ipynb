# %% [markdown]
# # MLFF

# %% [markdown]
# ### Content   <a name="content"></a>

# %% [markdown]
# 1. [Set a "seed" for all the libraries involved in the randomness](#1)
# 2. [Upload the datasets](#2)
# 3. [Create the dataset ](#3)
# 4. [MLFF](#4)
# 5. [Training loop](#5)
# 6. [Validation](#6)
# 7. [Evaluation](#7)

# %% [markdown]
# ## Set a "seed" for all the libraries involved in the randomness <a name="1"></a>

# %%
import torch
import numpy as np
import random
import os

def set_seed(seed=42):
    # Set seed for Python's random module
    random.seed(seed)
    
    # Set seed for NumPy
    np.random.seed(seed)
    
    # Set seed for PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # If using multi-GPU
    
    # Ensure deterministic operations in PyTorch
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Run this once at the start of your notebook
set_seed(42)

# %% [markdown]
# ## Upload the datasets <a name="2"></a>

# %%
# !pip install --upgrade numexpr

# %%
import pandas as pd

# 1. Load your master CSV dataset
df = pd.read_csv('AID499704_CIDs_SIDs_SMILESs_targets.csv') 

df['target'].value_counts()
# Out:
# target
# 1    1132
# 0     993
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train, temp = train_test_split(df, test_size=0.2, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)

print(f"Train size: {len(train)}")
print(f"Val size:   {len(val)}")
print(f"Test size:  {len(test)}")
# Out:
# Train size: 1700
# Val size:   212
# Test size:  213

# %%
print(train.shape)
train.head()
# Out:
# (1700, 4)
#            CID        SID                                             SMILES  \
# 192     723526  103709905             C1=CC=C(C=C1)CCN2C(=NNC2=S)C3=CC=NC=C3
# 1232  12166995  103710665  CC[C@H]1CN2CC[C@@H]1C[C@@H]2[C@H](C3=C4C=C(C=C...
# 480    2951665  103713101  C1CC(CCC1CN2C(=O)C3=CC=CC=C3NC2=S)C(=O)NCCC4=C...
# 1110    826108  103709705                   CCCC1=C(NC2=C(C1=O)C=C(C=C2)Br)C
# 1302   2835722  103713338  C1CCN(CC1)C2=C(C(=C(C=C2C(=O)N3CC(=O)NC4=CC=CC...
#
#       target
# 192        1
# 1232       1
# 480        1
# 1110       1
# 1302       1

# %%
print(test.shape)
test.head()
# Out:
# (213, 4)
#             CID        SID                                             SMILES  \
# 817    24052388  103711300  CCCCN(C)C(=O)C1=C(C2=C(S1)N=CN(C2=O)CC(=O)N(CC...
# 422     5334245  103710954  C1=CC=C2C(=C1)C(=CN2CC3=C(C=C(C=C3)Cl)Cl)/C=C(...
# 715     3132590  103713061  CCOC(=O)C1=C(NC2=C(C1C3=C(C=C(C=C3)Cl)Cl)C(=O)...
# 1469  135440409  103710901  CCN1C(=NN(C1=S)CN2CCN(CC2)CC3=CC4=C(C=C3)OCO4)...
# 1231   16237397  103709881  CCCCCCCCCCOC(=O)CN1C(=[N+](C2=CC=CC=C21)C)C.[Cl-]
#
#       target
# 817        0
# 422        1
# 715        1
# 1469       0
# 1231       1

# %%
print(val.shape)
val.head()
# Out:
# (212, 4)
#            CID        SID                                             SMILES  \
# 1680   6616740  103712208  COCCNC(=O)C1=CC(=C(C=C1)NCCC2=CC=C(C=C2)Cl)S(=...
# 964   45488650  103711690             CC(C)CNC(=O)C1=CN=C(N=C1NC2CCCC2)NCCCN
# 1823  45488866  103712640  CC1CCN(CC1)CC2=CC=C(C=C2)NC(=O)C3=CC4=C(S3)C5=...
# 270   45488399  103710451  CCCCCN(C(CC)C1=NC2=CC=CC=C2C(=O)N1C3=CC=CC=C3O...
# 2013  45489144  103713971  CC1=CC(=CC(=[N+]1OC(=O)N(C2=CC=CC=C2)C3=CC=CC=...
#
#       target
# 1680       1
# 964        1
# 1823       1
# 270        0
# 2013       1

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Create the dataset  <a name="3"></a>

# %%
from torch_geometric.data import Data
from rdkit import Chem

def df_to_graph(row):
    # 1. Convert SMILES to an RDKit molecule object
    mol = Chem.MolFromSmiles(row['SMILES'])
    
    # Optional: Handle cases where RDKit fails to parse the SMILES
    if mol is None:
        return None 
        
    node_features = []
    for atom in mol.GetAtoms():
        # A 6-dimensional feature vector for every single atom
        features = [
            atom.GetAtomicNum(),           # 1. Identity
            atom.GetDegree(),              # 2. Connectivity
            int(atom.GetIsAromatic()),     # 3. Heme-stacking ability
            atom.GetFormalCharge(),        # 4. Vacuole pH interaction
            atom.GetTotalNumHs(),          # 5. Saturation
            int(atom.GetProp('_BinaryHB')) if atom.HasProp('_BinaryHB') else 0 # 6. HB Logic
        ]
        node_features.append(features)
        
    x = torch.tensor(node_features, dtype=torch.float)
    
    edge_index = []
    for bond in mol.GetBonds():
        i, j = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
        edge_index.append([i, j])
        edge_index.append([j, i])
        
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    
    return Data(x=x, edge_index=edge_index, y=torch.tensor([row['target']], dtype=torch.float))

# Update the graph creation step to filter out any None results
train_graphs = [g for g in [df_to_graph(row) for _, row in train.iterrows()] if g is not None]
val_graphs = [g for g in [df_to_graph(row) for _, row in val.iterrows()] if g is not None]
test_graphs = [g for g in [df_to_graph(row) for _, row in test.iterrows()] if g is not None]

# %%
from torch_geometric.loader import DataLoader

# Create batches (e.g., batch size 32)
train_loader = DataLoader(train_graphs, batch_size=32, shuffle=True)
val_loader = DataLoader(val_graphs, batch_size=32)
test_loader = DataLoader(test_graphs, batch_size=32)

# %%
import torch
import numpy as np
from sklearn.preprocessing import MinMaxScaler

class DataTransformer:
    def __init__(self, n_qubits):
        self.n_qubits = n_qubits
        self.scaler = MinMaxScaler(feature_range=(0, np.pi))

    def transform(self, latent_features):
        """
        Transforms GNN latent embeddings into the [0, pi] range 
        required for QML AngleEmbedding.
        """
        # Convert to numpy for scaling
        data = latent_features.detach().cpu().numpy()
        
        # Apply scaling to fit the Quantum input requirements
        scaled_data = self.scaler.fit_transform(data)
        
        return torch.tensor(scaled_data, dtype=torch.float32)

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## MLFF   <a name="4"></a>

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv, global_add_pool

class SimpleMLFF(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, n_qubits):
        super(SimpleMLFF, self).__init__()
        # Use the passed dimensions to set up your layers
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)
        
        # Mapping for the prediction layer
        self.lin = nn.Linear(hidden_dim, 1)
        
        # Storing parameters for later use (e.g., in a Quantum layer)
        self.latent_dim = latent_dim
        self.n_qubits = n_qubits

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        
        # Message passing layers
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        
        # Global pooling to create a molecular representation
        x = global_add_pool(x, batch)
        
        # Final prediction
        return self.lin(x)

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Trainign loop <a name="5"></a>

# %%
import torch.optim as optim
from torch_geometric.nn import GCNConv, global_mean_pool

# Initialize the Hybrid Model (from previous steps)
n_qubits = 10      # Number of qubits
input_dim = 6      # Number of features per node
hidden_dim = 64    # Size of hidden layers
latent_dim = 32    # Size of the output embedding

# Define device globally
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Move model to device
model = SimpleMLFF(input_dim=6, hidden_dim=64, latent_dim=32, n_qubits=10)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = torch.nn.BCEWithLogitsLoss()

# Inside training and validation loops, move each batch
def train_one_epoch(loader, model, optimizer, criterion):
    model.train()
    total_loss = 0
    for batch in loader:
        # Move batch to the same device as the model
        batch = batch.to(device) 
        
        optimizer.zero_grad()
        output = model(batch)
        loss = criterion(output.view(-1), batch.y.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def validate(loader, model, criterion):
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in loader:
            # Move batch to the same device as the model
            batch = batch.to(device)
            
            output = model(batch)
            loss = criterion(output.view(-1), batch.y.view(-1))
            val_loss += loss.item()
    return val_loss / len(loader)

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Validation <a name="6"></a>

# %%
# Initialize best_val_loss before the loop
best_val_loss = float('inf')

# --- Combined Training and Validation Loop ---
for epoch in range(50):
    # Training
    train_loss = train_one_epoch(train_loader, model, optimizer, criterion) 
    
    # Validation (now matches the 3-argument signature)
    val_loss = validate(val_loader, model, criterion) 
    
    print(f"Epoch {epoch+1:03d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    
    # Save the model if it's the best one so far
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_hybrid_model.pth')
        print(f"--> New best model saved at epoch {epoch+1}")
# Out:
# Epoch 001 | Train Loss: 0.7757 | Val Loss: 0.7240
# --> New best model saved at epoch 1
# Epoch 002 | Train Loss: 0.7240 | Val Loss: 0.6998
# --> New best model saved at epoch 2
# Epoch 003 | Train Loss: 0.6988 | Val Loss: 0.6942
# --> New best model saved at epoch 3
# Epoch 004 | Train Loss: 0.6785 | Val Loss: 0.7098
# Epoch 005 | Train Loss: 0.6806 | Val Loss: 0.6882
# --> New best model saved at epoch 5
# Epoch 006 | Train Loss: 0.6809 | Val Loss: 0.7108
# Epoch 007 | Train Loss: 0.6821 | Val Loss: 0.6877
# --> New best model saved at epoch 7
# Epoch 008 | Train Loss: 0.7068 | Val Loss: 0.6825
# --> New best model saved at epoch 8
# Epoch 009 | Train Loss: 0.7404 | Val Loss: 0.6841
# Epoch 010 | Train Loss: 0.6730 | Val Loss: 0.7047
# Epoch 011 | Train Loss: 0.6790 | Val Loss: 0.6810
# --> New best model saved at epoch 11
# Epoch 012 | Train Loss: 0.6806 | Val Loss: 0.7305
# Epoch 013 | Train Loss: 0.7198 | Val Loss: 0.7171
# Epoch 014 | Train Loss: 0.6752 | Val Loss: 0.8763
# Epoch 015 | Train Loss: 0.6801 | Val Loss: 0.6774
# --> New best model saved at epoch 15
# Epoch 016 | Train Loss: 0.6907 | Val Loss: 0.6809
# Epoch 017 | Train Loss: 0.6703 | Val Loss: 0.8268
# Epoch 018 | Train Loss: 0.6718 | Val Loss: 0.6767
# --> New best model saved at epoch 18
# Epoch 019 | Train Loss: 0.6577 | Val Loss: 0.7627
# Epoch 020 | Train Loss: 0.6775 | Val Loss: 0.7063
# Epoch 021 | Train Loss: 0.6721 | Val Loss: 0.6764
# --> New best model saved at epoch 21
# Epoch 022 | Train Loss: 0.6738 | Val Loss: 0.7244
# Epoch 023 | Train Loss: 0.6678 | Val Loss: 0.6829
# Epoch 024 | Train Loss: 0.6602 | Val Loss: 0.6842
# Epoch 025 | Train Loss: 0.6657 | Val Loss: 0.6886
# Epoch 026 | Train Loss: 0.6860 | Val Loss: 0.7174
# Epoch 027 | Train Loss: 0.6625 | Val Loss: 0.7236
# Epoch 028 | Train Loss: 0.6470 | Val Loss: 0.7089
# Epoch 029 | Train Loss: 0.6626 | Val Loss: 0.8254
# Epoch 030 | Train Loss: 0.6680 | Val Loss: 0.7540
# Epoch 031 | Train Loss: 0.6714 | Val Loss: 0.6734
# --> New best model saved at epoch 31
# Epoch 032 | Train Loss: 0.6717 | Val Loss: 0.6777
# Epoch 033 | Train Loss: 0.6664 | Val Loss: 0.8156
# Epoch 034 | Train Loss: 0.6739 | Val Loss: 0.6764
# Epoch 035 | Train Loss: 0.6557 | Val Loss: 0.7027
# Epoch 036 | Train Loss: 0.6885 | Val Loss: 0.6832
# Epoch 037 | Train Loss: 0.6583 | Val Loss: 0.6707
# --> New best model saved at epoch 37
# Epoch 038 | Train Loss: 0.6613 | Val Loss: 0.6734
# Epoch 039 | Train Loss: 0.6518 | Val Loss: 0.6970
# Epoch 040 | Train Loss: 0.6577 | Val Loss: 0.6755
# Epoch 041 | Train Loss: 0.6545 | Val Loss: 0.7062
# Epoch 042 | Train Loss: 0.6956 | Val Loss: 0.6825
# Epoch 043 | Train Loss: 0.6774 | Val Loss: 0.7866
# Epoch 044 | Train Loss: 0.6637 | Val Loss: 0.6714
# Epoch 045 | Train Loss: 0.6494 | Val Loss: 0.6874
# Epoch 046 | Train Loss: 0.6822 | Val Loss: 0.6772
# Epoch 047 | Train Loss: 0.6831 | Val Loss: 0.6735
# Epoch 048 | Train Loss: 0.6616 | Val Loss: 0.7613
# Epoch 049 | Train Loss: 0.6860 | Val Loss: 0.6709
# Epoch 050 | Train Loss: 0.6598 | Val Loss: 0.6729

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Evaluation  <a name="7"></a>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import torch

def evaluate_model(loader, model):
    model.eval()  # Set model to evaluation mode
    all_preds = []
    all_targets = []
    
    # Ensure model is on the correct device
    model = model.to(device)
    
    with torch.no_grad():
        for batch in loader:
            # Explicitly move batch to the same device as the model
            batch = batch.to(device)
            
            # Forward pass
            output = model(batch)
            
            # Since BCEWithLogitsLoss was used, output is a logit. 
            # Apply sigmoid and threshold at 0.5
            preds = (torch.sigmoid(output) > 0.5).float()
            
            # Move results back to CPU for numpy conversion
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(batch.y.cpu().numpy())
            
    # Calculate metrics
    acc = accuracy_score(all_targets, all_preds)
    prec = precision_score(all_targets, all_preds, zero_division=0)
    rec = recall_score(all_targets, all_preds, zero_division=0)
    f1 = f1_score(all_targets, all_preds, zero_division=0)
    
    return acc, prec, rec, f1

# Execute evaluation
acc, prec, rec, f1 = evaluate_model(test_loader, model)
print(f"Test Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1-Score: {f1:.4f}")
# Out:
# Test Accuracy: 0.6385 | Precision: 0.5931 | Recall: 0.8269 | F1-Score: 0.6908

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def plot_confusion_matrix(loader, model):
    model.eval()
    all_preds = []
    all_targets = []
    
    model = model.to(device)
    
    with torch.no_grad():
        for batch in loader:
            # FIX: Ensure batch and model are on the same device
            batch = batch.to(device)
            
            output = model(batch)
            preds = (torch.sigmoid(output) > 0.5).float()
            
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(batch.y.cpu().numpy())
            
    cm = confusion_matrix(all_targets, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
    disp.plot(cmap='Blues')
    plt.title("Model Confusion Matrix")
    plt.show()

# Run the plot
plot_confusion_matrix(test_loader, model)

# %% [markdown]
# [<a href="#content">Back to top</a>]
